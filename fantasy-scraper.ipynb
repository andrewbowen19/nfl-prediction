# %%
import requests
import pandas as pd
from typing import List
import numpy as np

# %% [markdown]
# This notebook is to pull in data from Pro Football Reference on Scoring and Fantasy Performance
#
# - [Sample Page](https://www.pro-football-reference.com/years/2023/fantasy.htm)

# %%
def clean_columns(columns: List[str]) -> List[str]:
    return [f"{c[0]}_{c[1]}".lower() if "Unnamed" not in c[0] else c[1].lower() for c in columns ]


# Get all fantasy results dating back to 2010
def get_fantasy_scoring(year: int) -> pd.DataFrame:
    url = f"https://www.pro-football-reference.com/years/{year}/fantasy.htm#fantasy"

    df = pd.read_html(url)[0]

    # clean up columns from multi-index
    old_cols = df.columns
    df.columns = clean_columns(old_cols)

    # Add year column
    df['year'] = [year for _ in range(len(df))]

    return df

all_data = []
for year in range (2023, 2000, -1):
    all_data.append(get_fantasy_scoring(year))

# %%
# Combine all years into one year
df = pd.concat(all_data)
df
# Out:
#       rk                 player   tm fantpos age games_g games_gs passing_cmp  \
# 0      1  Christian McCaffrey*+  SFO      RB  27      16       16           0
# 1      2          CeeDee Lamb*+  DAL      WR  24      17       17           0
# 2      3             Josh Allen  BUF      QB  27      17       17         385
# 3      4          Tyreek Hill*+  MIA      WR  29      16       16           0
# 4      5           Jalen Hurts*  PHI      QB  25      17       17         352
# ..   ...                    ...  ...     ...  ..     ...      ...         ...
# 546  530           Troy Walters  MIN      WR  25       6        0           0
# 547  531            Craig Yeast  NYJ      WR  25      11        0           0
# 548  532             David Dunn  OAK      WR  29      10        0           0
# 549  533           Nate Jacquet  MIN      WR  26      10        0           0
# 550  534         Scott Mitchell  CIN      QB  33       1        0           4
#
#     passing_att passing_yds  ... scoring_2pm scoring_2pp fantasy_fantpt  \
# 0             0           0  ...         NaN         NaN            324
# 1             0           0  ...           1         NaN            268
# 2           579        4306  ...         NaN           3            393
# 3             0           0  ...         NaN         NaN            257
# 4           538        3858  ...         NaN         NaN            357
# ..          ...         ...  ...         ...         ...            ...
# 546           0           0  ...         NaN         NaN             -2
# 547           0           0  ...         NaN         NaN             -2
# 548           0           0  ...         NaN         NaN             -3
# 549           0           0  ...         NaN         NaN             -4
# 550          12          38  ...         NaN         NaN             -4
#
#     fantasy_ppr fantasy_dkpt fantasy_fdpt fantasy_vbd fantasy_posrank  \
# 0         391.3        399.3        357.8         157               1
# 1         403.2        411.2        335.7         131               1
# 2         392.6        420.6        410.6         122               1
# 3         376.4        380.4        316.9         120               2
# 4         356.8        382.8        371.8          89               2
# ..          ...          ...          ...         ...             ...
# 546        -2.0         -1.0         -2.0         NaN             186
# 547        -2.0         -1.0         -2.0         NaN             187
# 548        -2.2         -0.2         -2.7         NaN             188
# 549        -4.0         -2.0         -4.0         NaN             189
# 550        -4.5         -1.5         -1.5         NaN              79
#
#     fantasy_ovrank  year
# 0                1  2023
# 1                2  2023
# 2                3  2023
# 3                4  2023
# 4                5  2023
# ..             ...   ...
# 546            NaN  2001
# 547            NaN  2001
# 548            NaN  2001
# 549            NaN  2001
# 550            NaN  2001
#
# [14159 rows x 34 columns]

# %%
# Add pro-bowl and all-pro flags
df['pro_bowl'] = df['player'].str.contains("*", regex=False)
df['all_pro'] = df['player'].str.contains("+", regex=False)

# Some basic cleaning steps of the combined dataframe
df['player'] = df['player'].str.replace("\*|\+", "", regex=True)#.replace("+", "")

# Remove any interim header rows
df['rank'] = df['rk']
df = df.drop(['rk'], axis=1)
df = df.loc[df['rank'] != "Rk"]

df
# Out:
#                   player   tm fantpos age games_g games_gs passing_cmp  \
# 0    Christian McCaffrey  SFO      RB  27      16       16           0
# 1            CeeDee Lamb  DAL      WR  24      17       17           0
# 2             Josh Allen  BUF      QB  27      17       17         385
# 3            Tyreek Hill  MIA      WR  29      16       16           0
# 4            Jalen Hurts  PHI      QB  25      17       17         352
# ..                   ...  ...     ...  ..     ...      ...         ...
# 546         Troy Walters  MIN      WR  25       6        0           0
# 547          Craig Yeast  NYJ      WR  25      11        0           0
# 548           David Dunn  OAK      WR  29      10        0           0
# 549         Nate Jacquet  MIN      WR  26      10        0           0
# 550       Scott Mitchell  CIN      QB  33       1        0           4
#
#     passing_att passing_yds passing_td  ... fantasy_ppr fantasy_dkpt  \
# 0             0           0          0  ...       391.3        399.3
# 1             0           0          0  ...       403.2        411.2
# 2           579        4306         29  ...       392.6        420.6
# 3             0           0          0  ...       376.4        380.4
# 4           538        3858         23  ...       356.8        382.8
# ..          ...         ...        ...  ...         ...          ...
# 546           0           0          0  ...        -2.0         -1.0
# 547           0           0          0  ...        -2.0         -1.0
# 548           0           0          0  ...        -2.2         -0.2
# 549           0           0          0  ...        -4.0         -2.0
# 550          12          38          0  ...        -4.5         -1.5
#
#     fantasy_fdpt fantasy_vbd fantasy_posrank fantasy_ovrank  year pro_bowl  \
# 0          357.8         157               1              1  2023     True
# 1          335.7         131               1              2  2023     True
# 2          410.6         122               1              3  2023    False
# 3          316.9         120               2              4  2023     True
# 4          371.8          89               2              5  2023     True
# ..           ...         ...             ...            ...   ...      ...
# 546         -2.0         NaN             186            NaN  2001    False
# 547         -2.0         NaN             187            NaN  2001    False
# 548         -2.7         NaN             188            NaN  2001    False
# 549         -4.0         NaN             189            NaN  2001    False
# 550         -1.5         NaN              79            NaN  2001    False
#
#     all_pro rank
# 0      True    1
# 1      True    2
# 2     False    3
# 3      True    4
# 4     False    5
# ..      ...  ...
# 546   False  530
# 547   False  531
# 548   False  532
# 549   False  533
# 550   False  534
#
# [13713 rows x 36 columns]

# %%
# Save Output to CSV file
df.to_csv("fantasy-scoring.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 # Save Output to CSV file
# ----> 2 df.to_csv("fantasy-scoring.csv", index=False)
#
# NameError: name 'df' is not defined
